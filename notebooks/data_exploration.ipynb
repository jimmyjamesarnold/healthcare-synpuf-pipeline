# %%
import pandas as pd

# check raw datasets
OP = pd.read_csv('../data/raw/DE1_0_2008_to_2010_Carrier_Claims_Sample_1A.csv')
OP.head()
# Out:
# /tmp/ipykernel_335801/2435454599.py:4: DtypeWarning: Columns (9,10,11,46,47,48,49,50,135,136,137,138,139,140,141) have mixed types. Specify dtype option on import or set low_memory=False.
#   OP = pd.read_csv('../data/raw/DE1_0_2008_to_2010_Carrier_Claims_Sample_1A.csv')
#         DESYNPUF_ID           CLM_ID  CLM_FROM_DT  CLM_THRU_DT ICD9_DGNS_CD_1  \
# 0  00013D2EFD8E45D1  887733386680966     20090725     20090725           7245
# 1  00013D2EFD8E45D1  887213386947664     20091014     20091014           3598
# 2  00013D2EFD8E45D1  887243388666441     20100401     20100401          29606
# 3  00013D2EFD8E45D1  887893388307089     20100817     20100817           8410
# 4  00013D2EFD8E45D1  887463387476539     20101105     20101105          29521
#
#   ICD9_DGNS_CD_2 ICD9_DGNS_CD_3 ICD9_DGNS_CD_4 ICD9_DGNS_CD_5 ICD9_DGNS_CD_6  \
# 0           7244           6272            NaN            NaN            NaN
# 1          27541            NaN            NaN            NaN            NaN
# ...

# %%
OP.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2370667 entries, 0 to 2370666
# Data columns (total 142 columns):
#  #    Column                         Dtype
# ---   ------                         -----
#  0    DESYNPUF_ID                    object
#  1    CLM_ID                         int64
#  2    CLM_FROM_DT                    int64
#  3    CLM_THRU_DT                    int64
#  4    ICD9_DGNS_CD_1                 object
#  5    ICD9_DGNS_CD_2                 object
#  6    ICD9_DGNS_CD_3                 object
#  7    ICD9_DGNS_CD_4                 object
#  8    ICD9_DGNS_CD_5                 object
#  9    ICD9_DGNS_CD_6                 object
#  10   ICD9_DGNS_CD_7                 object
#  11   ICD9_DGNS_CD_8                 object
#  12   PRF_PHYSN_NPI_1                float64
#  13   PRF_PHYSN_NPI_2                float64
#  14   PRF_PHYSN_NPI_3                float64
#  15   PRF_PHYSN_NPI_4                float64
#  16   PRF_PHYSN_NPI_5                float64
# ...
